# %% [markdown]
# <a href="https://colab.research.google.com/github/aarongrashious/data-visualization/blob/main/data_visualiation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
iris=sns.load_dataset("iris")

# %%
sns.barplot(data=iris,x="sepal_length")
# Out:
# <Axes: xlabel='sepal_length'>

# %% [markdown]
# heatmap

# %%
corr=iris.corr()
# Out:
# <ipython-input-29-f1cce85a88c7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=iris.corr()

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.boxplot(data=iris)
# Out:
# <Axes: >

# %% [markdown]
# histogram

# %%
import numpy as np

# %%
x = np.random.randn(1000)
plt.hist(x,bins=50)
# Out:
# (array([ 1.,  1.,  0.,  0.,  2.,  0.,  4.,  2.,  6., 10.,  8., 12., 19.,
#         20., 15., 31., 33., 32., 43., 31., 50., 47., 47., 54., 50., 62.,
#         63., 54., 38., 36., 35., 33., 32., 23., 12., 16., 22., 10., 10.,
#          9.,  6.,  9.,  3.,  0.,  4.,  1.,  3.,  0.,  0.,  1.]),
#  array([-3.22618876, -3.09466787, -2.96314699, -2.83162611, -2.70010523,
#         -2.56858434, -2.43706346, -2.30554258, -2.1740217 , -2.04250081,
#         -1.91097993, -1.77945905, -1.64793817, -1.51641728, -1.3848964 ,
#         -1.25337552, -1.12185464, -0.99033375, -0.85881287, -0.72729199,
#         -0.59577111, -0.46425022, -0.33272934, -0.20120846, -0.06968758,
#          0.06183331,  0.19335419,  0.32487507,  0.45639595,  0.58791684,
#          0.71943772,  0.8509586 ,  0.98247948,  1.11400037,  1.24552125,
#          1.37704213,  1.50856301,  1.6400839 ,  1.77160478,  1.90312566,
#          2.03464654,  2.16616743,  2.29768831,  2.42920919,  2.56073007,
#          2.69225096,  2.82377184,  2.95529272,  3.0868136 ,  3.21833449,
#          3.34985537]),
#  <BarContainer object of 50 artists>)

# %%
plt.imshow(corr)
